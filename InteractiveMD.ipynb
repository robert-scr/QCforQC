# %%
# !pip install mdtraj nglview -q
from google.colab import output
output.enable_custom_widget_manager()

# WICHTIG: Hier deine echten RAW-URLs zu den beiden Dateien aus deinem GitHub-Repo eintragen!
# !wget -q "https://raw.githubusercontent.com/robert-scr/QCforQC/main/topology.pdb"
# !wget -q "https://raw.githubusercontent.com/robert-scr/QCforQC/main/reduced_traj.dcd"

# %%
import mdtraj as md
import nglview as nv

traj = md.load("reduced_traj.dcd", top="topology.pdb")
view = nv.show_mdtraj(traj)
view.clear_representations()
view.add_cartoon('all', color='sstruc') 
view.add_licorice('resname PUS', opacity=1.0) 
view.center()
view
